# %%
from vec import Vec
import vecutil

# %% [markdown]
# ### Task 5.12.1

# %%
def move2board(y):
    return (1 / y['y3']) * y

# %%
v = Vec({'y1','y2','y3'}, {'y1':3, 'y2':2, 'y3':2})
move2board(v)
# Out:
# Vec({'y3', 'y1', 'y2'},{'y3': 1.0, 'y1': 1.5, 'y2': 1.0})
